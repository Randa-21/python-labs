# %%
print("Read 10 Numbers :")

counter = 0
sum = 0

while True:
    number = float(input("Read number"))

    if number < 0:
        print("can not Read Negative Number :")
        continue

    if number == 0:
        break

    if number % 2 == 0:
        sum += number

    counter += 1

    if counter == 10:
        break

print("Sum of Even Numbers = ", sum)
# Out:
# Read 10 Numbers :
# Read number 12
# Read number 22
# Read number 42
# Read number 34
# Read number 14
# Read number 23
# Read number 25
# Read number 26
# Read number 27
# Read number 15
# Sum of Even Numbers =  150.0

# %%
print("Read  Number to Generate Multiplication Tabel :")

number = int(input("Read number"))

for x in range(1, number + 1, 1):

    if x == 3:
        continue

    product = x * 12

    if product >= 50:
        break

    print(x, " x ", 12, " = ", (x * 12))
# Out:
# Read  Number to Generate Multiplication Tabel :
# Read number 12
# 1  x  12  =  12
# 2  x  12  =  24
# 4  x  12  =  48

# %%
counter = 1

while True:

    number = int(input("Guess number"))  # خمن رقم

    if number >= 1 and number <= 20:
        print("Guess Correctly : in Attempts :", counter)
        break
    else:
        counter += 1
        print("Error Guess and Total Attempts Number = ", counter)
        continue
# Out:
# Guess number 22
# Error Guess and Total Attempts Number =  2
# Guess number 99
# Error Guess and Total Attempts Number =  3
# Guess number 77
# Error Guess and Total Attempts Number =  4
# Guess number 66
# Error Guess and Total Attempts Number =  5
# Guess number 44
# Error Guess and Total Attempts Number =  6
# Guess number 88
# Error Guess and Total Attempts Number =  7
# Guess number 666
# Error Guess and Total Attempts Number =  8
# Guess number 0
# Error Guess and Total Attempts Number =  9
# Guess number 0
# Error Guess and Total Attempts Number =  10
# Guess number 0
# Error Guess and Total Attempts Number =  11
# Guess number 88
# Error Guess and Total Attempts Number =  12
# Guess number 25
# Error Guess and Total Attempts Number =  13
# Guess number 20
# Guess Correctly : in Attempts : 13

# %%
counter = 0

number = int(input("Enter Number :"))

for x in range(1, number + 1, 1):

    if number > 50:
        print("Stop Counting ")
        break

    if x % 4 == 0:
        counter += 1

    if x % 8 == 0:
        continue

print("Number Divided by 4 = ", counter)

# %%
for i in range(1, 6):

    for j in range(1, i + 1):

        if j == 3:
            continue

        if i * j > 6:
            break

        print(j, end=" ")

    print()
# Out:
# 1
# 1 2
# 1 2
# 1
# 1
